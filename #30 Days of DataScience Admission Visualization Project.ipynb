# %% [markdown]
# # Admission's Project

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# Exploring the dataset
data = pd.read_csv('adm_data.csv')
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
data.std()
# Out:
# Serial No.           115.614301
# GRE Score             11.473646
# TOEFL Score            6.069514
# University Rating      1.143728
# SOP                    1.006869
# LOR                    0.898478
# CGPA                   0.596317
# Research               0.498362
# Chance of Admit        0.142609
# dtype: float64

# %%
# Plotting a scatter between Serial No. & CGPA
plt.scatter(data['Serial No.'], data['CGPA'], color='brown')
plt.xlabel = ('Serial')
plt.ylabel = ('GPA')
plt.show()

# %%
#plotting in seaborn
sb.scatterplot(data=data, x="Serial No.", y="CGPA")
plt.Xlabel = ('Serial')
plt.Ylabel = ('GPA')
plt.show()
