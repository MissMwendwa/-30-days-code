# %% [markdown]
# # Seaborn Plotting

# %%
# Imports
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Creating the datasets
x = ['Salary', 'Age', 'Budget', 'Expense', 'Net Savings']
y = [52, 24, 27, 32, 45]

# %%
# Creating the plot
ax = sns.stripplot(x, y)
ax.set(xlabel = 'Payment Details', ylabel = 'Amount *1000')

plt.title('My first plot')
plt.show()
# Out:
# C:\Users\Miss Gloriah\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Plotting the Iris Dataset
sns.set(style="whitegrid")
  
# loading data-set
iris = sns.load_dataset('iris')
  
# plotting strip plot with seaborn
ax = sns.stripplot(x='species', y='sepal_length', data=iris)
  
# giving title to the plot
plt.title('Graph')
  
# function to show plot
plt.show()

# %%
# Second Plot of the Iris dataset
sns.set(style="whitegrid")
  
# loading data-set
iris = sns.load_dataset('iris')
  
# plotting strip plot with seaborn
ax = sns.swarmplot(x='species', y='sepal_length', data=iris)
  
# giving title to the plot
plt.title('Graph')
  
# function to show plot
plt.show()
